# %%
from rightmove_webscraper import rightmove_data

# %%
url_london = 'https://www.rightmove.co.uk/property-to-rent/find.html?searchType=RENT&locationIdentifier=REGION%5E87490&insId=1&radius=0.0&minPrice=&maxPrice=&minBedrooms=&maxBedrooms=&displayPropertyType=&maxDaysSinceAdded=&sortByPriceDescending=&_includeLetAgreed=on&primaryDisplayPropertyType=&secondaryDisplayPropertyType=&oldDisplayPropertyType=&oldPrimaryDisplayPropertyType=&letType=&letFurnishType=&houseFlatShare='
url_london_1100_1200_studio = 'https://www.rightmove.co.uk/property-to-rent/find.html?locationIdentifier=REGION%5E87490&maxBedrooms=0&minBedrooms=0&maxPrice=1200&minPrice=1100&includeLetAgreed=false'

# %%
# %%time
london_1100_1200_studio = rightmove_data(url_london_1100_1200_studio)
# Out:
# CPU times: user 7.46 s, sys: 120 ms, total: 7.58 s
# Wall time: 12.7 s

# %%
london_1100_1200_studio.results_count
# Out:
# 376

# %%
london_1100_1200_studio.get_results
# Out:
#      price              type  \
# 0     1100       Studio flat
# 1     1196  Studio apartment
# 2     1199       Studio flat
# 3     1127       Studio flat
# 4     1150       Studio flat
# 5     1166       Studio flat
# 6     1200  Studio apartment
# 7     1150       Studio flat
# 8     1192       Studio flat
# 9     1200       Studio flat
# 10    1200       House share
# 11    1148       Studio flat
# 12    1183       Studio flat
# 13    1196       Studio flat
# 14    1170       Studio flat
# 15    1170       Studio flat
# 16    1127       Studio flat
# 17    1170       Studio flat
# 18    1170       Studio flat
# 19    1170       Studio flat
# 20    1170       Studio flat
# 21    1150       Studio flat
# 22    1170       Studio flat
# 23    1148       Studio flat
# 24    1105       Studio flat
# 25    1127       Studio flat
# 26    1175       Studio flat
# 27    1191       Studio flat
# 28    1100       Studio flat
# 29    1150       Studio flat
# ..     ...               ...
# ...
